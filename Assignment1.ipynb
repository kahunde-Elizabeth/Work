# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_excel('Student_performance.xlsx')
data
# Out:
#     Access_no  gender  age                  course  DSC3108  DSC3114  MTH3108  \
# 0         123  female   21        Computer_Science     89.0     88.0       72
# 1         415    male   22        Computer_Science     91.0     98.0       88
# 2         321    male   21            Data_Science     73.0     70.0       38
# 3         124  female   21  Information_Technology     30.0     40.0       60
# 4         314  female   22        Computer_Science     70.0     75.0       78
# 5         891    male   21  Information_Technology     25.0     70.0       69
# 6         729  female   22            Data_Science     65.0     80.0       38
# 7         892  female   21            Data_Science     90.0     95.0       92
# 8         545    male   22                     NaN     54.0     69.0       78
# 9         718  female   21  Information_Technology      NaN     78.0       79
# 10        390    male   22        Computer_Science     45.0      NaN       79
#
#     SYE3104
# 0        65
# ...

# %%
data.isnull().sum()
# Out:
# Access_no    0
# gender       0
# age          0
# course       1
# DSC3108      1
# DSC3114      1
# MTH3108      0
# SYE3104      0
# dtype: int64

# %%
data['course'].fillna(value=data['course'].mode()[0], inplace=True)
data
# Out:
#     Access_no  gender  age                  course  DSC3108  DSC3114  MTH3108  \
# 0         123  female   21        Computer_Science     89.0     88.0       72
# 1         415    male   22        Computer_Science     91.0     98.0       88
# 2         321    male   21            Data_Science     73.0     70.0       38
# 3         124  female   21  Information_Technology     30.0     40.0       60
# 4         314  female   22        Computer_Science     70.0     75.0       78
# 5         891    male   21  Information_Technology     25.0     70.0       69
# 6         729  female   22            Data_Science     65.0     80.0       38
# 7         892  female   21            Data_Science     90.0     95.0       92
# 8         545    male   22        Computer_Science     54.0     69.0       78
# 9         718  female   21  Information_Technology      NaN     78.0       79
# 10        390    male   22        Computer_Science     45.0      NaN       79
#
#     SYE3104
# 0        65
# ...

# %%
data.describe(include='all')
# Out:
#          Access_no  gender        age            course    DSC3108    DSC3114  \
# count    11.000000      11  11.000000                11  10.000000  10.000000
# unique         NaN       2        NaN                 3        NaN        NaN
# top            NaN  female        NaN  Computer_Science        NaN        NaN
# freq           NaN       6        NaN                 5        NaN        NaN
# mean    496.545455     NaN  21.454545               NaN  63.200000  76.300000
# std     278.903339     NaN   0.522233               NaN  24.220285  16.418486
# min     123.000000     NaN  21.000000               NaN  25.000000  40.000000
# 25%     317.500000     NaN  21.000000               NaN  47.250000  70.000000
# 50%     415.000000     NaN  21.000000               NaN  67.500000  76.500000
# 75%     723.500000     NaN  22.000000               NaN  85.000000  86.000000
# max     892.000000     NaN  22.000000               NaN  91.000000  98.000000
#
#           MTH3108    SYE3104
# ...

# %%
data['DSC3108'].fillna(value=data['DSC3108'].median(),inplace=True)
data
# Out:
#     Access_no  gender  age                  course  DSC3108  DSC3114  MTH3108  \
# 0         123  female   21        Computer_Science     89.0     88.0       72
# 1         415    male   22        Computer_Science     91.0     98.0       88
# 2         321    male   21            Data_Science     73.0     70.0       38
# 3         124  female   21  Information_Technology     30.0     40.0       60
# 4         314  female   22        Computer_Science     70.0     75.0       78
# 5         891    male   21  Information_Technology     25.0     70.0       69
# 6         729  female   22            Data_Science     65.0     80.0       38
# 7         892  female   21            Data_Science     90.0     95.0       92
# 8         545    male   22        Computer_Science     54.0     69.0       78
# 9         718  female   21  Information_Technology     63.2     78.0       79
# 10        390    male   22        Computer_Science     45.0      NaN       79
#
#     SYE3104
# 0        65
# ...

# %%
data['DSC3114'].fillna(value=data['DSC3114'].mean(),inplace=True)
data
# Out:
#     Access_no  gender  age                  course  DSC3108  DSC3114  MTH3108  \
# 0         123  female   21        Computer_Science     89.0     88.0       72
# 1         415    male   22        Computer_Science     91.0     98.0       88
# 2         321    male   21            Data_Science     73.0     70.0       38
# 3         124  female   21  Information_Technology     30.0     40.0       60
# 4         314  female   22        Computer_Science     70.0     75.0       78
# 5         891    male   21  Information_Technology     25.0     70.0       69
# 6         729  female   22            Data_Science     65.0     80.0       38
# 7         892  female   21            Data_Science     90.0     95.0       92
# 8         545    male   22        Computer_Science     54.0     69.0       78
# 9         718  female   21  Information_Technology     63.2     78.0       79
# 10        390    male   22        Computer_Science     45.0     76.3       79
#
#     SYE3104
# 0        65
# ...

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Information Technology

# %%
no_IT= data[data['course'] == "Information_Technology"]['course'].count()
#View results
no_IT
# Out:
# np.int64(3)

# %%
# TOTAL NUMBER OF COURSES
Total_number=data['course'].count()
Total_number
# Out:
# np.int64(11)

# %%
prob_IT=no_IT/Total_number
prob_IT
# Out:
# np.float64(0.2727272727272727)

# %% [markdown]
# The probability is 27.2%

# %% [markdown]
# Females studying Computer Science

# %%
no_Fe= data[data['gender'] == "female"]['gender'].count()
#View results
no_Fe
# Out:
# np.int64(6)

# %%
no_cps= data[data['course'] == "Computer_Science"]['course'].count()
#View results
no_cps
# Out:
# np.int64(5)

# %%
filtered_data = (data['course'] == 'Computer_Science') & (data['gender'] == 'female')
filtered_data
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# dtype: bool

# %%
femalecps_count = data[filtered_data]["course"].count()
#View result
femalecps_count
# Out:
# np.int64(2)

# %%
probability_femalecps=femalecps_count/no_cps
probability_femalecps
# Out:
# np.float64(0.4)

# %% [markdown]
# The probabilty is 40%

# %% [markdown]
# MALE DOING DATASCIENCE

# %%
no_DS=data[data['course'] == "Data_Science"]['course'].count()
#View results
no_DS
# Out:
# np.int64(3)

# %%
Group_MDS=(data['course']=='Data_Science')& (data["gender"]=="male")
Group_MDS
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# dtype: bool

# %%
MaDS_count=data[Group_MDS]["course"].count()
MaDS_count
# Out:
# np.int64(1)

# %%
probability_MaDS=MaDS_count/no_DS
probability_MaDS
# Out:
# np.float64(0.3333333333333333)

# %% [markdown]
# The probability is 33.3%
